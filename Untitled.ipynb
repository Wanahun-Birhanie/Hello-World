# %%
import matplotlib.pyplot as plt

x = ["Wanahun","Yisehak","Maedot","Senait"]
y = [40,6,36,3]
plt.plot(x,y,"--", marker = "*", ms = 20, mec = 'r',mfc = 'b')
plt.grid()
plt.show()

# %%
from sympy import *
from numpy import *
x, y = symbols('x,y')
f = Function('f')(x,y)
f = x**3*y+x**2+y**3+((x*y)/(x**2+y**2))
f
# Out:
# x**3*y + x**2 + x*y/(x**2 + y**2) + y**3

# %%
f.diff(x)
# Out:
# 3*x**2*y - 2*x**2*y/(x**2 + y**2)**2 + 2*x + y/(x**2 + y**2)

# %%
f.diff(x,y)
# Out:
# 8*x**2*y**2/(x**2 + y**2)**3 + 3*x**2 - 2*x**2/(x**2 + y**2)**2 - 2*y**2/(x**2 + y**2)**2 + 1/(x**2 + y**2)

# %%
f.diff(y)
# Out:
# x**3 - 2*x*y**2/(x**2 + y**2)**2 + x/(x**2 + y**2) + 3*y**2

# %%
f.integrate(x)
# Out:
# x**4*y/4 + x**3/3 + x*y**3 + y*log(x**2 + y**2)/2

# %%
f.integrate(y)
# Out:
# x**3*y**2/2 + x**2*y + x*log(x**2 + y**2)/2 + y**4/4

# %%
f.integrate((x,-1,0),(y,1,2))
# Out:
# -5*log(5)/4 + log(2)/2 + log(4) + 89/24

# %%
i = 0
while i<=5:
    print(i)
    if i==3:
        break
    i+=1
# Out:
# 0
# 1
# 2
# 3

# %%
i = 0
while i<=5:
    i+=1
    if i==3:
        continue
    print(i)
# Out:
# 1
# 2
# 4
# 5
# 6

# %%
fruits = ["apple", "banana", "cherry"]
for x in fruits:
    print(x)
# Out:
# apple
# banana
# cherry

# %%
adj = ["red", "big", "tasty"]
fruits = ["apple", "banana", "cherry"]

for x in adj:
    for y in fruits:
        print(x, y)
# Out:
# red apple
# red banana
# red cherry
# big apple
# big banana
# big cherry
# tasty apple
# tasty banana
# tasty cherry

# %%
def function():
    print("Hello Everybody")

# %%
function()
# Out:
# Hello Everybody

# %%
def my_function(fname):
    print(fname + " Refsnes")

my_function("Emil")
my_function("Tobias")
my_function("Linus")
# Out:
# Emil Refsnes
# Tobias Refsnes
# Linus Refsnes

# %%
def my_function(*kids):
    print("The youngest child is " + kids[2])

my_function("Emil", "Tobias", "Linus")
# Out:
# The youngest child is Linus

# %%
def my_function(**kid):
    print("His last name is " + kid["lname"])

my_function(fname = "Tobias", lname = "Refsnes")
# Out:
# His last name is Refsnes

# %%
def my_function(country = "Norway"):
    print("I am from " + country)

my_function("Sweden")
my_function("India")
my_function()
my_function("Brazil")
# Out:
# I am from Sweden
# I am from India
# I am from Norway
# I am from Brazil

# %%
Child = ["Wanahun","Tigist","Mihretabe","Messeret","Yirgalem","Desalegn","Atikilt"]
Father = ["Birhanie"]
G_father = ["Tessema"]
for i in Child:
    for j in Father:
        for k in G_father:
             print(i,j,k, sep=": ")
# Out:
# Wanahun: Birhanie: Tessema
# Tigist: Birhanie: Tessema
# Mihretabe: Birhanie: Tessema
# Messeret: Birhanie: Tessema
# Yirgalem: Birhanie: Tessema
# Desalegn: Birhanie: Tessema
# Atikilt: Birhanie: Tessema

# %%
ዓመት = int(input('ዓመተ ምህረት ያስገቡ፡ '))
ዓመተ_ዓለም = 5500 + ዓመት
መጠነ_ራብዕ = ዓመተ_ዓለም%4

while መጠነ_ራብዕ<4:
    መጠነ_ራብዕ += 1
    if መጠነ_ራብዕ==0:
        print(f"ያስገቡት ዓመት {ዓመት} ዓ.ም ሲሆን፤ የ{ዓመት} ዓመተ ምህረት ወንጌላዊዉ ወይንም ዘመኑ፤ ዘመነ ዮሃንስ ይሆናል፡፡")
    elif መጠነ_ራብዕ==1:
        print(f"ያስገቡት ዓመት {ዓመት} ዓ.ም ሲሆን፤ የ{ዓመት} ዓመተ ምህረት ወንጌላዊዉ ወይንም ዘመኑ፤ ዘመነ ማቲዎስ ይሆናል፡፡")
    elif መጠነ_ራብዕ==2:
        print(f"ያስገቡት ዓመት {ዓመት} ዓ.ም ሲሆን፤ የ{ዓመት} ዓመተ ምህረት ወንጌላዊዉ ወይንም ዘመኑ፤ ዘመነ ማርቆስ ይሆናል፡፡")
    else:
        print(f"ያስገቡት ዓመት {ዓመት} ዓ.ም ሲሆን፤ የ{ዓመት} ዓመተ ምህረት ወንጌላዊዉ ወይንም ዘመኑ፤ ዘመነ ሉቃስ ይሆናል፡፡")
    break
print("ውድ ኢትዮጵያዊያን አባቶቻችን ያቆዩልንን ዘመን አይሽሬ፤ አስደማሚና አኩሪ ታሪአክዊ ቅርስ ለምን ማስጠበቅ አቃተን፡?")
# Out:
# ዓመተ ምህረት ያስገቡ፡ 2016
# ያስገቡት ዓመት 2016 ዓ.ም ሲሆን፤ የ2016 ዓመተ ምህረት ወንጌላዊዉ ወይንም ዘመኑ፤ ዘመነ ማቲዎስ ይሆናል፡፡
# ውድ ኢትዮጵያዊያን አባቶቻችን ያቆዩልንን ዘመን አይሽሬ፤ አስደማሚና አኩሪ ታሪአክዊ ቅርስ ለምን ማስጠበቅ አቃተን፡?

# %%
i = 1
while i < 6:
    print(i)
    i += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
i = 1
while i < 6:
    print(i)
    i += 1
else:
    print("i is no longer less than 6")
# Out:
# 1
# 2
# 3
# 4
# 5
# i is no longer less than 6

# %%
for x in range(6):
    if x == 3: 
        break
    print(x)
else:
    print("Finally finished!")
# Out:
# 0
# 1
# 2

# %%
def addition():
    return 3+6

# %%
def Sum(x):
    return x+100
Sum(100)
# Out:
# 200

# %%
def Sum(x,y):
    return x+y
Sum(12/8,9)
# Out:
# 10.5

# %%
def myfunction(fname):
    print(fname+" " + 'Birhanie')

# %%
myfunction("Wanahun")
# Out:
# Wanahun Birhanie

# %%
def my_function(**kid):
    print("His last name is " + kid["lname"])

my_function(fname = "Tobias", lname = "Refsnes")
# Out:
# His last name is Refsnes

# %%
def my_function(child3, child2, child1):
    print("The youngest child is " + child3)

my_function(child1 = "Emil", child2 = "Tobias", child3 = "Linus")
# Out:
# The youngest child is Linus

# %%
def my_fun(**kid):
    print("The youngest baby is "+kid["lname"])
my_fun(fname="Wanahun",lname="Birhanie")
# Out:
# The youngest baby is Birhanie

# %%
def my_function(country = "Norway"):
    print("I am from " + country)

my_function("Sweden")
my_function("India")
my_function()
my_function("Brazil")
# Out:
# I am from Sweden
# I am from India
# I am from Norway
# I am from Brazil

# %%
def my_function(food):
    for x in food:
        print(x)

fruits = ["apple", "banana", "cherry"]

my_function(fruits)
# Out:
# apple
# banana
# cherry

# %%
def myfunction(food):
    for x in food:
        print(x)
fruit = ["Banana","Orange","Mango","Lemon","Papaya"]
myfunction(fruit)
# Out:
# Banana
# Orange
# Mango
# Lemon
# Papaya

# %%
def tri_recursion(k):
    if(k > 0):
        result = k + tri_recursion(k - 1)
        print(result)
    else:
        result = 0
    return result

print("\n\nRecursion Example Results")
tri_recursion(6)
# Out:
# Recursion Example Results
# 1
# 3
# 6
# 10
# 15
# 21
# 21
